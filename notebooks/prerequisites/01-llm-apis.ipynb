# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="low"
)

print(response.choices[0].message.content)
# Out:
# - lantern
# - meadow
# - quantum
# - ripple
# - compass
# - velvet
# - ember
# - zephyr
# - mosaic
# - sunset

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=167, prompt_tokens=24, total_tokens=191, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=128, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %% [markdown]
# ### Google genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant",
              "can you print 15 random words?"]
)

print(response.text)
# Out:
# Okay, here are 15 random words for you:
#
# 1.  **Galaxy**
# 2.  **Whisper**
# 3.  **Journey**
# 4.  **Crimson**
# 5.  **Boulder**
# 6.  **Flicker**
# 7.  **Serene**
# 8.  **Wander**
# 9.  **Echo**
# 10. **Cascade**
# 11. **Glimmer**
# 12. **Azure**
# 13. **Zephyr**
# 14. **Enigma**
# 15. **Verdant**

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 20 random words?"}
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Cake
# 2. Space
# 3. Helicopter
# 4. Pineapple
# 5. Computer
# 6. Bicycle
# 7. Banana
# 8. Guitar
# 9. Snowflake
# 10. Perfume
# 11. Luggage
# 12. Coffee
# 13. Telescope
# 14. Harmonica
# 15. Starfish
# 16. Submarine
# 17. Butterfly
# 18. Parakeet
# 19. Fountain
# 20. Dictionary
